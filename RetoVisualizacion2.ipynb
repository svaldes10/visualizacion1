# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "datasets/top250-00-19.csv"
df = pd.read_csv(url)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                 Name        Position  Age     Team_from     League_from  \
# 0          Luís Figo    Right Winger   27  FC Barcelona          LaLiga
# 1      Hernán Crespo  Centre-Forward   25         Parma         Serie A
# 2      Marc Overmars     Left Winger   27       Arsenal  Premier League
# 3  Gabriel Batistuta  Centre-Forward   31    Fiorentina         Serie A
# 4     Nicolas Anelka  Centre-Forward   21   Real Madrid          LaLiga
#
#         Team_to League_to     Season  Market_value  Transfer_fee
# 0   Real Madrid    LaLiga  2000-2001           NaN      60000000
# 1         Lazio   Serie A  2000-2001           NaN      56810000
# 2  FC Barcelona    LaLiga  2000-2001           NaN      40000000
# 3       AS Roma   Serie A  2000-2001           NaN      36150000
# 4      Paris SG   Ligue 1  2000-2001           NaN      34500000

# %%
df.tail()
# Out:
#                Name            Position  Age       Team_from   League_from  \
# 4695  Jasmin Kurtic  Attacking Midfield   29        Atalanta       Serie A
# 4696      Tchê Tchê    Central Midfield   25       Palmeiras       Série A
# 4697  Silvan Widmer          Right-Back   25  Udinese Calcio       Serie A
# 4698     Yuya Osako      Second Striker   28      1. FC Köln  2.Bundesliga
# 4699   Kyle Bartley         Centre-Back   27         Swansea  Championship
#
#             Team_to     League_to     Season  Market_value  Transfer_fee
# 4695           SPAL       Serie A  2018-2019     5000000.0       4800000
# 4696    Dynamo Kyiv  Premier Liga  2018-2019     3000000.0       4800000
# 4697       FC Basel  Super League  2018-2019     8500000.0       4500000
# 4698  Werder Bremen  1.Bundesliga  2018-2019     4500000.0       4500000
# 4699      West Brom  Championship  2018-2019     3500000.0       4500000

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4700 entries, 0 to 4699
# Columns: 10 entries, Name to Transfer_fee
# dtypes: float64(1), int64(2), object(7)
# memory usage: 367.3+ KB

# %%
df.columns
# Out:
# Index(['Name', 'Position', 'Age', 'Team_from', 'League_from', 'Team_to',
#        'League_to', 'Season', 'Market_value', 'Transfer_fee'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4700, step=1)

# %%
print(df.columns)

df.drop(['Position', 'Name'], axis=1, inplace=True)
print(df.columns)
df.head()
# Out:
# Index(['Name', 'Position', 'Age', 'Team_from', 'League_from', 'Team_to',
#        'League_to', 'Season', 'Market_value', 'Transfer_fee'],
#       dtype='object')
# Index(['Age', 'Team_from', 'League_from', 'Team_to', 'League_to', 'Season',
#        'Market_value', 'Transfer_fee'],
#       dtype='object')
#    Age     Team_from     League_from       Team_to League_to     Season  \
# 0   27  FC Barcelona          LaLiga   Real Madrid    LaLiga  2000-2001
# 1   25         Parma         Serie A         Lazio   Serie A  2000-2001
# 2   27       Arsenal  Premier League  FC Barcelona    LaLiga  2000-2001
# 3   31    Fiorentina         Serie A       AS Roma   Serie A  2000-2001
# 4   21   Real Madrid          LaLiga      Paris SG   Ligue 1  2000-2001
#
#    Market_value  Transfer_fee
# 0           NaN      60000000
# 1           NaN      56810000
# 2           NaN      40000000
# 3           NaN      36150000
# 4           NaN      34500000

# %%
df.set_index('Age')
# Out:
#           Team_from     League_from        Team_to     League_to     Season  \
# Age
# 27     FC Barcelona          LaLiga    Real Madrid        LaLiga  2000-2001
# 25            Parma         Serie A          Lazio       Serie A  2000-2001
# 27          Arsenal  Premier League   FC Barcelona        LaLiga  2000-2001
# 31       Fiorentina         Serie A        AS Roma       Serie A  2000-2001
# 21      Real Madrid          LaLiga       Paris SG       Ligue 1  2000-2001
# ..              ...             ...            ...           ...        ...
# 29         Atalanta         Serie A           SPAL       Serie A  2018-2019
# 25        Palmeiras         Série A    Dynamo Kyiv  Premier Liga  2018-2019
# 25   Udinese Calcio         Serie A       FC Basel  Super League  2018-2019
# 28       1. FC Köln    2.Bundesliga  Werder Bremen  1.Bundesliga  2018-2019
# 27          Swansea    Championship      West Brom  Championship  2018-2019
#
#      Market_value  Transfer_fee
# Age
# ...

# %%
df.describe()
# Out:
#                Age  Market_value  Transfer_fee
# count  4700.000000  3.440000e+03  4.700000e+03
# mean     24.338723  8.622469e+06  9.447586e+06
# std       3.230809  8.795181e+06  1.043772e+07
# min       0.000000  5.000000e+04  8.250000e+05
# 25%      22.000000  3.500000e+06  4.000000e+06
# 50%      24.000000  6.000000e+06  6.500000e+06
# 75%      27.000000  1.000000e+07  1.082000e+07
# max      35.000000  1.200000e+08  2.220000e+08

# %%
x = df['Age'].value_counts()
x
# Out:
# 24    536
# 25    524
# 23    519
# 26    481
# 22    461
# 27    404
# 21    371
# 28    327
# 20    302
# 29    223
# 19    165
# 30    157
# 18     82
# 31     59
# 32     30
# 17     23
# 33     15
# 16     10
# 34      5
# 35      4
# 15      1
# 0       1
# Name: Age, dtype: int64

# %%
x.plot(kind = "bar")

# %%
x.plot(kind = "barh")

# %%
sns.scatterplot(x = 'Age', y = 'League_to', data = df)
sns.set(rc={'figure.figsize':(20,11)})
plt.title('Edad en base a la futura liga')
plt.show()

# %%
df['Age'].plot(kind = 'hist',
              figsize =(20,10))

# %%
df['Transfer_fee'] = df['Transfer_fee'].astype(int)
df.corr()
# Out:
#                    Age  Market_value  Transfer_fee
# Age           1.000000      0.142739     -0.001803
# Market_value  0.142739      1.000000      0.830573
# Transfer_fee -0.001803      0.830573      1.000000

# %%
sns.lmplot(x='Market_value',
          y='Age',
          data=df,
          fit_reg=False,
          )
plt.title('Age vs Market Value')
# Out:
# Text(0.5, 1.0, 'Age vs Market Value')

# %%
sns.boxplot(data=df.loc[:,['Age']])

# %%
pip install statsmodels
# Out:
# ...
#      |████████████████████████████████| 9.9 MB 4.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 233 kB 68.6 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %%
model = sm.OLS.from_formula('Age ~ Market_value', data = df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    Age   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     71.50
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):           4.03e-17
# Time:                        07:10:05   Log-Likelihood:                -8785.6
# No. Observations:                3440   AIC:                         1.758e+04
# Df Residuals:                    3438   BIC:                         1.759e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
ax = sns.regplot(x = 'Market_value',
                y = 'Age',
                data = df,
                x_estimator = np.mean,
                )
