# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
df=pd.read_csv('datasets/antropometria-dataset.csv')
df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
model=sm.OLS.from_formula('diastol ~ sistol',data= df)
result=model.fit()
result.summary()
# Out:
# 0         1.893285
# 1        -4.309897
# 2       -13.528652
# 3         9.252594
# 4        -1.684914
#            ...
# 18635   -24.873679
# 18636   -42.920565
# 18637   -58.311255
# 18638   -26.498798
# 18639    21.313660
# Length: 18640, dtype: float64

# %%
model=sm.OLS.from_formula('peso ~ cadera',data= df)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   peso   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                 2.748e+04
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        01:33:21   Log-Likelihood:                -69160.
# No. Observations:               18032   AIC:                         1.383e+05
# Df Residuals:                   18030   BIC:                         1.383e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -30.0972      0.578    -52.090      0.000     -31.230     -28.965
# ...

# %%
model=sm.OLS.from_formula('peso ~ cadera',data= df)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   peso   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                 2.748e+04
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        01:54:36   Log-Likelihood:                -69160.
# No. Observations:               18032   AIC:                         1.383e+05
# Df Residuals:                   18030   BIC:                         1.383e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -30.0972      0.578    -52.090      0.000     -31.230     -28.965
# ...

# %%
model=sm.OLS.from_formula('diastol ~ sistol + edad + peso + cintura',data= df)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                diastol   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     3812.
# Date:                Thu, 21 Oct 2021   Prob (F-statistic):               0.00
# Time:                        01:52:26   Log-Likelihood:                -63952.
# No. Observations:               18032   AIC:                         1.279e+05
# Df Residuals:                   18027   BIC:                         1.280e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     20.3297      0.520     39.089      0.000      19.310      21.349
# ...

# %%
import statistics

statistics.median(result.resid)
# Out:
# -0.0021017816189328187
